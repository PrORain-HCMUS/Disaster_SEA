# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Data

# %%
df = pd.read_excel(r'C:\Users\Admin\Desktop\Disaster_SEA\data\disaster_sea.xlsx')
df.head(5)
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2000-0038-PHL       No    nat-hyd-flo-fla        Natural      Hydrological
# 1  2000-0066-PHL       No    nat-hyd-flo-coa        Natural      Hydrological
# 2  2000-0082-IDN       No    nat-hyd-mmw-mud        Natural      Hydrological
# 3  2000-0089-PHL       No    nat-geo-vol-ash        Natural       Geophysical
# 4  2000-0108-IDN       No    nat-bio-epi-vir        Natural        Biological
#
#          Disaster Type Disaster Subtype External IDs    Event Name  ISO  ...  \
# 0                Flood      Flash flood          NaN           NaN  PHL  ...
# 1                Flood    Coastal flood          NaN           NaN  PHL  ...
# 2  Mass movement (wet)         Mudslide          NaN           NaN  IDN  ...
# 3    Volcanic activity         Ash fall          NaN     Mt. Mayon  PHL  ...
# 4             Epidemic    Viral disease          NaN  Dengue fever  IDN  ...
#
#   Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# 0                             NaN                                       NaN
# 1                             NaN                                       NaN
# 2                             NaN                                       NaN
# 3                             NaN                                       NaN
# 4                             NaN                                       NaN
#
#   Insured Damage ('000 US$) Insured Damage, Adjusted ('000 US$)  \
# 0                       NaN                                 NaN
# 1                       NaN                                 NaN
# 2                       NaN                                 NaN
# 3                       NaN                                 NaN
# 4                       NaN                                 NaN
#
#   Total Damage ('000 US$) Total Damage, Adjusted ('000 US$)        CPI  \
# 0                  4080.0                            7219.0  56.514291
# 1                     NaN                               NaN  56.514291
# 2                 11600.0                           20526.0  56.514291
# 3                  2214.0                            3918.0  56.514291
# 4                     NaN                               NaN  56.514291
#
#                                          Admin Units  Entry Date  Last Update
# 0  [{"adm2_code":24275,"adm2_name":"Agusan Del No...  2004-10-27   2023-09-25
# 1      [{"adm2_code":24203,"adm2_name":"Tawi-tawi"}]  2003-07-01   2023-09-25
# 2         [{"adm2_code":18035,"adm2_name":"Brebes"}]  2005-07-21   2023-09-25
# 3          [{"adm2_code":24240,"adm2_name":"Albay"}]  2005-06-01   2023-09-25
# 4                                                NaN  2003-07-01   2023-09-25
#
# [5 rows x 46 columns]

# %%
df.shape
# Out:
# (1278, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 46 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   DisNo.                                     1278 non-null   object
#  1   Historic                                   1278 non-null   object
#  2   Classification Key                         1278 non-null   object
#  3   Disaster Group                             1278 non-null   object
#  4   Disaster Subgroup                          1278 non-null   object
#  5   Disaster Type                              1278 non-null   object
#  6   Disaster Subtype                           1278 non-null   object
#  7   External IDs                               286 non-null    object
#  8   Event Name                                 380 non-null    object
#  9   ISO                                        1278 non-null   object
#  10  Country                                    1278 non-null   object
#  11  Subregion                                  1278 non-null   object
#  12  Region                                     1278 non-null   object
#  13  Location                                   1255 non-null   object
#  14  Origin                                     569 non-null    object
#  15  Associated Types                           479 non-null    object
#  16  OFDA/BHA Response                          1278 non-null   object
#  17  Appeal                                     1278 non-null   object
#  18  Declaration                                1278 non-null   object
#  19  AID Contribution ('000 US$)                84 non-null     float64
#  20  Magnitude                                  452 non-null    float64
#  21  Magnitude Scale                            1129 non-null   object
#  22  Latitude                                   305 non-null    float64
#  23  Longitude                                  305 non-null    float64
#  24  River Basin                                162 non-null    object
#  25  Start Year                                 1278 non-null   int64
#  26  Start Month                                1277 non-null   float64
#  27  Start Day                                  1189 non-null   float64
#  28  End Year                                   1278 non-null   int64
#  29  End Month                                  1271 non-null   float64
#  30  End Day                                    1189 non-null   float64
#  31  Total Deaths                               947 non-null    float64
#  32  No. Injured                                447 non-null    float64
#  33  No. Affected                               1072 non-null   float64
#  34  No. Homeless                               139 non-null    float64
#  35  Total Affected                             1186 non-null   float64
#  36  Reconstruction Costs ('000 US$)            2 non-null      float64
#  37  Reconstruction Costs, Adjusted ('000 US$)  2 non-null      float64
#  38  Insured Damage ('000 US$)                  24 non-null     float64
#  39  Insured Damage, Adjusted ('000 US$)        24 non-null     float64
#  40  Total Damage ('000 US$)                    497 non-null    float64
#  41  Total Damage, Adjusted ('000 US$)          492 non-null    float64
#  42  CPI                                        1247 non-null   float64
#  43  Admin Units                                1132 non-null   object
#  44  Entry Date                                 1278 non-null   object
#  45  Last Update                                1278 non-null   object
# dtypes: float64(20), int64(2), object(24)
# memory usage: 459.4+ KB

# %%
attributes = pd.read_csv(r'C:\Users\Admin\Desktop\Disaster_SEA\data\attributes.csv')
attributes
# Out:
#                                   Column name  \
# 0                                     Dis No.
# 1                                    Historic
# 2                          Classification Key
# 3                              Disaster Group
# 4                           Disaster Subgroup
# 5                               Disaster Type
# 6                            Disaster Subtype
# 7                                External IDs
# 8                                  Event Name
# 9                                         ISO
# 10                                    Country
# 11                                  Subregion
# 12                                     Region
# 13                                   Location
# 14                                     Origin
# 15                           Associated Types
# 16                              OFDA Response
# 17                                     Appeal
# 18                                Declaration
# 19                           Aid Contribution
# 20                                  Magnitude
# 21                            Magnitude Scale
# 22                                   Latitude
# 23                                  Longitude
# 24                                River Basin
# 25                                 Start Year
# 26                                Start Month
# 27                                  Start Day
# 28                                   End Year
# 29                                  End Month
# 30                                    End Day
# 31                               Total Deaths
# 32                                No. Injured
# 33                               No. Affected
# 34                               No. Homeless
# 35                             Total Affected
# 36            Reconstruction Costs (‘000 US$)
# 37  Reconstruction Costs, Adjusted (‘000 US$)
# 38                  Insured Damage (‘000 US$)
# 39        Insured Damage, Adjusted (‘000 US$)
# 40                    Total Damage (‘000 US$)
# 41          Total Damage, Adjusted (‘000 US$)
# 42                                        CPI
# 43                                Admin Units
# 44                                 Entry Date
# 45                                Last Update
#
#                                           Description  \
# 0   A unique 8-digit identifier including the year...
# 1   Binary field specifying whether or not the dis...
# 2   A unique 15-character string identifying disas...
# 3   The disaster group, i.e., “Natural” or “Techno...
# 4                              The disaster subgroup.
# 5                                  The disaster type.
# 6                               The disaster subtype.
# 7   List of identifiers for external resources (GL...
# 8   Short specification for disaster identificatio...
# 9   The International Organization for Standardiza...
# 10  Country where the disaster occurred and had an...
# 11  Subregion where the disaster occurred based on...
# 12  Region or continent where the disaster occurre...
# 13  Geographical location name as specified in the...
# 14  Additional specifications on the contextual fa...
# 15  List of secondary disaster types cascading fro...
# 16  Binary field specifying whether or not the Off...
# 17  Binary field specifying whether or not there w...
# 18  Binary field specifying whether a state of eme...
# 19  The total amount (in thousands of US$ at the t...
# 20              The intensity of a specific disaster.
# 21      The associated unit for the Magnitude column.
# 22  North-South coordinates mainly for earthquakes...
# 23  East-West coordinates mainly for earthquakes a...
# 24  Name of affected river basins, typically used ...
# 25                Year of occurrence of the disaster.
# 26  Month of occurrence of the disaster. For sudde...
# 27  Day of occurrence of the disaster. For sudden-...
# 28                       Year of disaster conclusion.
# 29  Month of conclusion of the disaster. For sudde...
# 30  Day of conclusion of the disaster. For sudden-...
# 31    Total fatalities (deceased and missing combined
# 32  Number of people with physical injuries, traum...
# 33  Number of people requiring immediate assistanc...
# 34  Number of people requiring shelter due to thei...
# 35  Total number of affected people (No Injured, N...
# 36  Costs for replacement of lost assets in thousa...
# 37  Reconstruction Costs (‘000 US$), adjusted for ...
# 38  Economic damage covered by insurance companies...
# 39  Insured Damage (‘000 US$) adjusted for inflati...
# 40  Value of all economic losses directly or indir...
# 41  Total Damage (‘000 US$) adjusted for inflation...
# 42  Consumer Price Index from OECD used to adjust ...
# 43  Collection of impacted Administrative Units fr...
# 44  The day on which the event record was created ...
# 45  The last modification of the event or one of i...
#
#                                           Explanation
# 0   Dis No.: A unique 8-digit identifier including...
# 1   Historic: Binary field specifying whether or n...
# 2   Classification Key: A unique 15-character stri...
# 3   Disaster Group: The disaster group, i.e., “Nat...
# 4          Disaster Subgroup: The disaster subgroup.;
# 5                  Disaster Type: The disaster type.;
# 6            Disaster Subtype: The disaster subtype.;
# 7   External IDs: List of identifiers for external...
# 8   Event Name: Short specification for disaster i...
# 9   ISO: The International Organization for Standa...
# 10  Country: Country where the disaster occurred a...
# 11  Subregion: Subregion where the disaster occurr...
# 12  Region: Region or continent where the disaster...
# 13  Location: Geographical location name as specif...
# 14  Origin: Additional specifications on the conte...
# 15  Associated Types: List of secondary disaster t...
# 16  OFDA Response: Binary field specifying whether...
# 17  Appeal: Binary field specifying whether or not...
# 18  Declaration: Binary field specifying whether a...
# 19  Aid Contribution: The total amount (in thousan...
# 20  Magnitude: The intensity of a specific disaster.;
# 21  Magnitude Scale: The associated unit for the M...
# 22  Latitude: North-South coordinates mainly for e...
# 23  Longitude: East-West coordinates mainly for ea...
# 24  River Basin: Name of affected river basins, ty...
# 25   Start Year: Year of occurrence of the disaster.;
# 26  Start Month: Month of occurrence of the disast...
# 27  Start Day: Day of occurrence of the disaster. ...
# 28            End Year: Year of disaster conclusion.;
# 29  End Month: Month of conclusion of the disaster...
# 30  End Day: Day of conclusion of the disaster. Fo...
# 31  Total Deaths: Total fatalities (deceased and m...
# 32  No. Injured: Number of people with physical in...
# 33  No. Affected: Number of people requiring immed...
# 34  No. Homeless: Number of people requiring shelt...
# 35  Total Affected: Total number of affected peopl...
# 36  Reconstruction Costs (‘000 US$): Costs for rep...
# 37  Reconstruction Costs, Adjusted (‘000 US$): Rec...
# 38  Insured Damage (‘000 US$): Economic damage cov...
# 39  Insured Damage, Adjusted (‘000 US$): Insured D...
# 40  Total Damage (‘000 US$): Value of all economic...
# 41  Total Damage, Adjusted (‘000 US$): Total Damag...
# 42  CPI: Consumer Price Index from OECD used to ad...
# 43  Admin Units: Collection of impacted Administra...
# 44  Entry Date: The day on which the event record ...
# 45  Last Update: The last modification of the even...

# %% [markdown]
# ### 4.1 What are the most common types of natural disasters that occurred in Southeast Asia from 2000 to early 2024?
# - (e.g., floods, typhoons, earthquakes, etc.)

# %%
df['Start Year'] = pd.to_datetime(df['Start Year'], format='%Y', errors= 'coerce').dt.year
df['End Year'] = pd.to_datetime(df['End Year'], format='%Y', errors= 'coerce').dt.year
modified_df = df[(df['Start Year'] >= 2000) & (df['End Year'] <= 2024)]

# %%
disaters_count = modified_df['Disaster Type'].value_counts().head(1)
disaters_count
# Out:
# Flood    595
# Name: Disaster Type, dtype: int64

# %% [markdown]
# ### 4.2 What are the main causes of natural disasters in Southeast Asia, and how do they differ between regions?
# - (e.g., climate change, tectonic activity, deforestation, etc.)

# %%
df['Disaster Subgroup'].unique()
# Out:
# array(['Hydrological', 'Geophysical', 'Biological', 'Climatological',
#        'Meteorological'], dtype=object)
